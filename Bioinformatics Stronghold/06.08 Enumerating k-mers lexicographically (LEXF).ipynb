# %%
f = open('rosalind_lexf.txt', 'r').read().strip().split('\n')
order, n = f[0].split(' '), int(f[1])
order.sort()
words = order
while len(words[0])<n:
    words=[letter+word for letter in order for word in words]
print('\n'.join(words))
# Out:
# AAA
# AAD
# AAH
# AAI
# AAL
# AAW
# AAZ
# ADA
# ADD
# ADH
# ADI
# ADL
# ADW
# ADZ
# AHA
# AHD
# AHH
# AHI
# AHL
# AHW
# AHZ
# AIA
# AID
# AIH
# AII
# AIL
# AIW
# AIZ
# ALA
# ALD
# ALH
# ALI
# ALL
# ALW
# ALZ
# AWA
# AWD
# AWH
# AWI
# AWL
# AWW
# AWZ
# AZA
# AZD
# AZH
# AZI
# AZL
# AZW
# AZZ
# DAA
# DAD
# DAH
# DAI
# DAL
# DAW
# DAZ
# DDA
# DDD
# DDH
# DDI
# DDL
# DDW
# DDZ
# DHA
# DHD
# DHH
# DHI
# DHL
# DHW
# DHZ
# DIA
# DID
# DIH
# DII
# DIL
# DIW
# DIZ
# DLA
# DLD
# DLH
# DLI
# DLL
# DLW
# DLZ
# DWA
# DWD
# DWH
# DWI
# DWL
# DWW
# DWZ
# DZA
# DZD
# DZH
# DZI
# DZL
# DZW
# DZZ
# HAA
# HAD
# HAH
# HAI
# HAL
# HAW
# HAZ
# HDA
# HDD
# HDH
# HDI
# HDL
# HDW
# HDZ
# HHA
# HHD
# HHH
# HHI
# HHL
# HHW
# HHZ
# HIA
# HID
# HIH
# HII
# HIL
# HIW
# HIZ
# HLA
# HLD
# HLH
# HLI
# HLL
# HLW
# HLZ
# HWA
# HWD
# HWH
# HWI
# HWL
# HWW
# HWZ
# HZA
# HZD
# HZH
# HZI
# HZL
# HZW
# HZZ
# IAA
# IAD
# IAH
# IAI
# IAL
# IAW
# IAZ
# IDA
# IDD
# IDH
# IDI
# IDL
# IDW
# IDZ
# IHA
# IHD
# IHH
# IHI
# IHL
# ...
